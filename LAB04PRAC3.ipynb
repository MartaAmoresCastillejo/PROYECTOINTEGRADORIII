# %%
import numpy as np 
import pandas as pd 
import sklearn as sk 
import matplotlib.pyplot as plt 
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv('enfermeria.csv', encoding = 'latin_1')
data
# Out:
#       parents_occupation childs_nursery family_form number_children  \
# 0                  usual         proper    complete               1
# 1                  usual         proper    complete               1
# 2                  usual         proper    complete               1
# 3                  usual         proper    complete               1
# 4                  usual         proper    complete               1
# ...                  ...            ...         ...             ...
# 12955         great_pret      very_crit      foster            more
# 12956         great_pret      very_crit      foster            more
# 12957         great_pret      very_crit      foster            more
# 12958         great_pret      very_crit      foster            more
# 12959         great_pret      very_crit      foster            more
#
#       housing_conditions financial_standing social_conditions  \
# 0             convenient         convenient           nonprob
# 1             convenient         convenient           nonprob
# 2             convenient         convenient           nonprob
# 3             convenient         convenient     slightly_prob
# 4             convenient         convenient     slightly_prob
# ...                  ...                ...               ...
# 12955           critical             inconv     slightly_prob
# 12956           critical             inconv     slightly_prob
# 12957           critical             inconv       problematic
# 12958           critical             inconv       problematic
# 12959           critical             inconv       problematic
#
#       health_conditions recommendation
# 0           recommended      recommend
# 1              priority       priority
# 2             not_recom      not_recom
# 3           recommended      recommend
# 4              priority       priority
# ...                 ...            ...
# 12955          priority     spec_prior
# 12956         not_recom      not_recom
# 12957       recommended     spec_prior
# 12958          priority     spec_prior
# 12959         not_recom      not_recom
#
# [12960 rows x 9 columns]

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.describe()
# Out:
#        parents_occupation childs_nursery family_form number_children  \
# count               12960          12960       12960           12960
# unique                  3              5           4               4
# top                 usual         proper    complete               1
# freq                 4320           2592        3240            3240
#
#        housing_conditions financial_standing social_conditions  \
# count               12960              12960             12960
# unique                  3                  2                 3
# top            convenient         convenient           nonprob
# freq                 4320               6480              4320
#
#        health_conditions recommendation
# count              12960          12960
# unique                 3              5
# top          recommended      not_recom
# freq                4320           4320

# %%
le = LabelEncoder()
for col in data.columns: #Cambiar los strings del dataframe de x
    if data[col].dtype == 'object':
        data[col] = le.fit_transform(data[col])

data
# Out:
#        parents_occupation  childs_nursery  family_form  number_children  \
# 0                       2               3            0                0
# 1                       2               3            0                0
# 2                       2               3            0                0
# 3                       2               3            0                0
# 4                       2               3            0                0
# ...                   ...             ...          ...              ...
# 12955                   0               4            2                3
# 12956                   0               4            2                3
# 12957                   0               4            2                3
# 12958                   0               4            2                3
# 12959                   0               4            2                3
#
#        housing_conditions  financial_standing  social_conditions  \
# 0                       0                   0                  0
# 1                       0                   0                  0
# 2                       0                   0                  0
# 3                       0                   0                  2
# 4                       0                   0                  2
# ...                   ...                 ...                ...
# 12955                   1                   1                  2
# 12956                   1                   1                  2
# 12957                   1                   1                  1
# 12958                   1                   1                  1
# 12959                   1                   1                  1
#
#        health_conditions  recommendation
# 0                      2               2
# 1                      1               1
# 2                      0               0
# 3                      2               2
# 4                      1               1
# ...                  ...             ...
# 12955                  1               3
# 12956                  0               0
# 12957                  2               3
# 12958                  1               3
# 12959                  0               0
#
# [12960 rows x 9 columns]

# %%
hierarchical_cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
labels = hierarchical_cluster.fit_predict(data)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
plt.scatter(, y, c=labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-572b9bdfce91> in <cell line: 1>()
# ----> 1 plt.scatter(x, y, c=labels)
#       2 plt.show()
#
# NameError: name 'x' is not defined
